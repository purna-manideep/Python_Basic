# %%
inte=int(input())
string1=input()
string2=input()
s1=len(string1)
s2=len(string2)
if s1>s2:
    print(s1-s2)
elif s2>s1:
    print(s2-s1)
# Out:
# 1
# mani
# deeep
# 1

# %%
for _ in range(int(input())):
    a=input()
    b=input()
    a1=[0]*26
    b1=[0]*26
    for ele in a:
        a1[ord(ele)-97]+=1;
    for ele in b:
        b1[ord(ele)-97]+=1;
    res=0;
    for i in range(26):
        res=res+(abs(a1[i]-b1[i]));
    print(res);
# Out:
# 4
# 0
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-0fd4afe9bd7b> in <module>
#       5     b1=[0]*26
#       6     for ele in a:
# ----> 7         a1[ord(ele)-97]+=1;
#       8     for ele in b:
#       9         b1[ord(ele)-97]+=1;
#
# IndexError: list index out of range

# %%
for _ in range(int(input())):
    a=input()
    b=input()
    a1=[0]*26
    b1=[0]*26
    for ele in a:
        a1[ord(ele)-97]+=1
    for ele in b:
        b1[ord(ele)-97]+=1
print(a)
print(b)
print(a1)
print(b1)

# %% [markdown]
# ### Function

# %%
def fun_name(arg1,arg2,...arg3):

# %%
# Passing parameters and return nothing
def add(x,y):
    print(x+y)
    return
add(-5,-6)
# Out:
# -11

# %%
# Passing parameters and return result
def add(x,y):
    return x+y
#print(add(4,5))
rs=add(4,5)
print(rs)
# Out:
# 9

# %%
n=int(input())
def ev_od():
    if (a%2)==0:
        return True
    return False
print(ev_od())
# Out:
# 4
# True

# %%
def isPrime(n):
    if a==2:
        return True
        for i in rage(2,a//2+1):
            if a%i==0:
                return True
            return False
isPrime(5)

# %%
# find out the given number is perfect or not
# find that thegiven year is leapyear or not

# %%
def fact(a):
    print(a)
n=int(input())

fact(n)

def fact(a):
    print(a)
# Out:
# 3
# 3

# %%
def add(num1,num2):
    return num1+num2

# %%
print(add(2,9))
# Out:
# 11

# %%
def division(a,b):
    return a/b
