# %%
nt=int(input())
for i in ragnge(1,nt+1):
    cost=list(map(int, input()))
    nu_p=int(input())
    for j in range(nu_p):
        cost=list(map(int, input()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-08d83be7cd9f> in <module>
# ----> 1 nt=int(ionput())
#       2 for i in ragnge(1,nt+1):
#       3     cost=list(map(int, input()))
#       4     nu_p=int(input())
#       5     for j in range(nu_p):
#
# NameError: name 'ionput' is not defined

# %%
inte=int(input())
string1=input()
string2=input()
s1=len(string1)
s2=len(string2)
if s1>s2:
    v=s1-s2
elif s2>s1:
    v=s2-s1
    
print(v)
# Out:
# 1
# mani
# deep mani
# 5
