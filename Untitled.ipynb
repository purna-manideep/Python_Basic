# %%
def sqr(x):
    return x*x
print(sqr(int(input())))
# Out:
# 23
# 529

# %%
# Out:
# 2
# 2
# 2 3
# 4
# 5
# 6

# %% [markdown]
# ######

# %%
i=int(input())
print("#")
for j in range(i):
    print("-" end="")
print("#")

# %%
j=int(input())
li=[]
for k in range(j):
    li.append(i)

# %%
n=int(input())
