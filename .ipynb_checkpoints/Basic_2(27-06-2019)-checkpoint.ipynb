# %%
text=input()
reverse_text=text[::-1]
for char in reverse_text:
    print(char)

# %%
[print(char)for char in input()[::-1]] # list comprahencive

# %%
#Porgrame to print the name in different order
#Ayyappa Bandi
#B. Ayyappa
first_lastname=input().split(" ")
lname,fname=first_lastname[::-1]
print(lname[0],fname,sep=". ")

# %%
# finding the average of the values
marks=input()
marks_list=list(map(int,marks.split()))
print(sum(marks_list)//len(marks_list))

# %%
s=""
print(type(s))

# %%
s=input()
s2=input()
print(s+s2,type(s))

# %%
s="1234"
s2=int(s)
print(s2,type(s),type(s2))

# %%
s1="1"
s2="2"
print(int(s1)+int(s2),type(s1))

# %% [markdown]
# ### string mathods  in python

# %%
s="Python programming"
print(len(s))# the function len() represents the length of the string

# %%
# string indexing
print(s[0])# the square brackets are used to writen the index values
print(s[17])
print(s[5])
print(s[-3])
print(s[18-3])

# %%
s[0]

# %%
s[0]='y'

# %%
# string slicinig
print(s[0:6])
print(s[7:18])
print(s[7:18:2])# here is for index incrimenting
print(s[0:6])
print(s[5:0:-1])# for reverse printiong based on index 
print(s[7:])
print(s[:])
print(s[::-1])

# %% [markdown]
# # string mathods

# %%
# The upper mathod used to conversthe case
v='python'
print(v.upper())
print(v)

# %%
j='python'
k=j.upper()
l=k.lower()
print(j)
print(k)
print(l)

# %% [markdown]
# # str.startswith(sub_string)

# %%
m='python'.lower()
sub='P'.lower()# mathod used to convert string case
print(m.startswith(sub))

# %%
m='python programming'
print(m.startswith('programming'))
print(m.endswith('ing'))

# %%
b='123ac'
print(b.isdigit())

# %%
c=input()
if c.isdigit():
    print('sucess',int(c))
else:
    print('i asked you to give number but u r input is wrong')

# %%
s='python programming'
result=s.split()
# print(result,type(result))
print(result[1],type(result[1]))

# %%
s='  purna  '
r=s.lstrip()
print(s.lstrip())
print(r)# removes the space on its left side
k=r.rstrip()
print(s.rstrip())
print(k)# removes the space on its right side

# %%
m=s.lstrip().rstrip()
print(m,len(m))

# %%
h=s.strip()
print(h,len(h))# usedto remove the spaces on both sides

# %% [markdown]
# ### str.isupper(),str.islower()

# %%
print(s.isupper())
print(s.islower())

# %% [markdown]
# ### isalpha()

# %%
s=input()
print(s.isalpha())

# %%
s='pythonPROGRAMMING'
print(s.swapcase())

# %%
s='pytHon pROGRAmming'
print(s.title())

# %% [markdown]
# ### Str.find(sub_string)

# %%
s='python'
print(s.find('o'))

# %%
s='python'
print(s.find('on'))

# %% [markdown]
# ### str.replace(old,new)

# %%
s='python'
print(s.replace('n','oon'))

# %% [markdown]
# ### str.rfind(sub)

# %%
t='python programming'
print(t.rfind('m'))

# %% [markdown]
# print(t.index('j'))

# %% [markdown]
# ### str.join(sequence_or_collection_of_items)

# %%
s=['p','r','o','g','r','a','m']
print(''.join(s))

# %%
s='apssdc tot'
s[0].upper()+''.join(s[1:])#+s[1:].upper()

# %%
h=s.capitalize()
print(h)

# %%
h.istitle()

# %%
s="Python"
list(s)

# %%
t=2
n=5
for i in range(n+1):
    print(t,'*',i,'=',t*i)

# %% [markdown]
# ### python data structure:
# * list
# * Tuples
# *

# %%
li=[1,'abc',45.09]# list is a data type of  mutable(changes the values)
li.append(34)

li

# %%
dir(list)# to find the functions as per the concept

# %%
li.insert(1,89)
li

# %%
li[2]=23
li

# %%
li[3]=13;li

# %%
li.pop(2);li

# %%
li.remove(89);
li

# %%
li.clear()
li

# %%
li1=[1,2,34,5]

# %%
del li1

# %%
li1

# %%
li=[1,3,5,7,9,2,4,6,8]
li.sort()

# %%
li

# %%
li.sort(reverse=True)

# %%
li

# %%
li[::-1]

# %%
li.reverse()

# %%
li

# %%
cli=li

# %%
cli

# %%
cli.append(345)

# %%
cli

# %%
li

# %%
li.pop()

# %%
li

# %%
cli

# %%
cli2=li.copy()
print(cli2,li)

# %%
cli2.append(45)

# %%
print(cli2,li)

# %%
li.extend(cli2)

# %%
li

# %%
cli2

# %%
lb=[1,2,3,4]
lc=[5,6,7,8]
print(lc,lb)

# %%
lb.extend(lc)

# %%
lb

# %%
lb.append(lc)

# %%
lb

# %%
lb[9]

# %%
lb[9][1]

# %%
li[-1]

# %%
li.count(4)

# %%
s=0
for i in li:
    s=s+1
print(s)

# %%
lk=[1,2,3,4,6]

# %%
print(lk)
# Out:
# [1, 2, 3, 4, 6]

# %%
l=[7,8,9]
l=l[::-1]
for i in l:
    lk.insert(1,i)

# %%
print(lk)
# Out:
# [1, 7, 8, 9, 2, 3, 4, 6]

# %%
print(sum(lk),max(lk),min(lk))
# Out:
# 40 9 1

# %%
l=list()

# %%
l
# Out:
# []

# %%
t=int(input())
j=0
for i in range(t):
    a=list(map(int,input().split()))
    print(sum(li))

# %%
t=int(input())
for i in range(t):
    s=input().split("+")
    li=[]
    for i in s:
        li.append(int(i))
    x=sorted(li)
    print(li[0])
    print(li[-1])
# Out:
# 0

# %%
t=int(input())
for  i in range(t):
    li=list(map())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-393c4dc69d40> in <module>
# ----> 1 t=int(input())
#       2 for  i in range(t):
#       3     li=list(map())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
t=int(input())
for  i in range(t):
    c0st_ballons=list(map(int,input().split()))
    n=int(input())
    for  j in range(n):
        k=list(map(int,input().split()))
# Out:
# 0

# %%
t=int(input())
for  i in range(t):
    cost_ballons=input()
    g_ballons,p_ballons=list(map(int,cost_ballons.split()))
    participants=int(input())
    for j in range(participants):
        status=list(map(int,input().split()))
# Out:
# 0

# %%
N_friends=int(input())
x=int(input())
for i in range(N_friends):
        y=int(input())
        if y>=x:
            print("YES")
        else:
            print("NO")
# Out:
# 5
# 100
# 0
# NO
# 0
# NO
# 0
# NO
# 0
# NO
# 0
# NO

# %%
num=int(input())
while num!=42:
# Out:
# 1 2 88 42 99

# %%
li=list(map(int,input().split()))
i=0
while li[i]!=42:
    print(li[i])
    i+=1
# Out:
# 1 2 88 42 98
# 1
# 2
# 88

# %%
li
type(li)
# Out:
# list

# %%
li[0]
# Out:
# 1
