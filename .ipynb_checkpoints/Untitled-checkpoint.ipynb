# %%
def sqr(x):
    return x*x
print(sqr(int(input())))
# Out:
# 23
# 529

# %%
# Out:
# 2
# 2
# 2 3
# 4
# 5
# 6

# %% [markdown]
# ######

# %%
i=int(input())
print("#")
for j in range(i):
    print("-" end="")
print("#")

# %%
j=int(input())
li=[]
for k in range(j):
    li.append(i)

# %%
t=int(input())
lftA=0
lftb=7
n=int(input())
for i in range(n):
    n=int(input())
    if n<=3:
        print("A")
    if n>=4:
        print("B")

# %%
lftA=0
lftb=7
k=abs(lftA/lftb)

# %%
n=list(map(int,input()))
u=len(n)
if u!=10:
    print("Illegal ISBN")
else:
    k=0
    for i in n:
        k=k+int(n[i])*i
    if (k/11):
        print("Legal ISBN")
    else:
        print("Illegal ISBN")
# Out:
# 1401601499
# Legal ISBN

# %%
n=list(map(int,input().split()
nu=0

for i in range(0,9):
           nu=nu+1
#for i in range(97,123):
 #   c=c+1
    
print(nu)
print(n)
# Out:
#   File "<ipython-input-10-6c1a84fdf447>", line 2
#     nu=0
#      ^
# SyntaxError: invalid syntax
