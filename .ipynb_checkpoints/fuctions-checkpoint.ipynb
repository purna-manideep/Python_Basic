# %%
# Function to check if a given number is Prime
def isPrime(n):
    flag = True
    for i in range(2, n//2+1):
        if n % i == 0:
            flag = False
            return flag
    return flag

isPrime(4)
# Out:
# False

# %%
s='apssdc tot'
s[0].upper()+''.join(s[1:])#+s[1:].upper()
# Out:
# 'Apssdc tot'

# %%
h=s.capitalize()
print(h)
# Out:
# Apssdc tot

# %%
h.istitle()
# Out:
# False

# %%
s="Python"
list(s)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
t=2
n=5
for i in range(n+1):
    print(t,'*',i,'=',t*i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c9853884b4fa> in <module>
#       1 t=2
#       2 n=5
# ----> 3 for i in n+1:
#       4     print(t,'*',i,'=',t*i)
#
# TypeError: 'int' object is not iterable
