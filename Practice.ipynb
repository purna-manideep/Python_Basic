# %%
n

# %%
tax=4*3.75

# %%
tax

# %%
e='mani\rdeep'

# %%
print(e)

# %%
print("""\
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")

# %%
# 1. Print given characters as a word with starting character capital form and remaining lower
# A P S S D C
# Apssdc

#s=input()
#s=s.replace(" ",'')
#type(s)
#s=s.capitalize()
#q=len(s)
#V=s[1:q]
#S=s[0]+V.lower()
#print(S,sep='')

# %%
def Cap(s):
    s=s.replace(" ",'')
    #type(s)
    #s=s.capitalize()
    q=len(s)
    V=s[1:q]
    S=s[0]+V.lower()
    return S
s=input()


print(Cap(s))
# Out:
# M ANI D E EP
# Manideep

# %%
char=input()
word=char.split()
u=''.join(word) #converting thelist into stirng
type(u)

# %%
# 2. Print the maximum length word of given words
# Hai hello world
# hello
# world
words=input().split()
length=[]
for word in words:
    length.append(len(word))
max_length=max(length)
for i in words:
    if max_length==len(i):
        print(i)

# %%
words=input().split()
[print(word) for word in words if max(list(map(len,words)))=len(words)

# %%
3. Print all the words which starts with the given character, If no words matches with the given condition you should print -1
#ramu ravi balu

s= input().split()
r=input()
for j in s:
    if j.startswith(r):
        print(j)
print(-1)

# %%
# 4. Print all the words which words not ends with vowels(a,e,i,o,u)
# ramu ravi balu raju mahesh

s= input().split()
r=['a','e','i','o','u']
for j in s:
    for i in r:
        if j.endswith(i):
            continue
print(j)
# Out:
# mani deep raja
# raja

# %%
# 5. Print all the words which word contains duplicate characters
# ramu akash balu
# akash
name=input().split()
for i in name:
    for ch in i:
        if i.count(ch)>1:
            print(i)
            break

# %%
#6. Swap the case of all characters in given string except last character
#HellowOrld
#hELLOWoRLd
s
s=input()
s[:-1].swapcase()+s[-1]

# %%
# 7. Print the number of words in a given string (here word starting character contains UPPER letter)
# HelloWorld
s=input()
count=0
for i in s:
    if i.isupper():
        count+=1
        #li.append(i)
        #for i in li:
print(count)

# %%
len(list(filter(str.isupper,input())))

# %%
### 1.Print even and odd numbers up to given range.

#### input : 10 
#### output:
#### even numbers -->  2,4,6,8,10
#### odd numbers --> 1,3,5,7,9
g=int(input())
ev=[]
od=[]
for i in range(0,g+1,2):
    ev.append(i)
for i in range(1,g+1,2):
    od.append(i)
print(ev)
print(od)
# Out:
# 10
# [0, 2, 4, 6, 8, 10]
# [1, 3, 5, 7, 9]

# %%
### 2.print given numbers prime or not.

#### input: --> 5 9
#### output: -->5  True
####                   9   False
s=[i for i in input().split()]
for i in s:
    if s%i

# %%
# hackerearth concatenate characters with n  number of inputs
loops = int()
inputs = []
s=""
for x in range(loops):
    inputs.append(input())
s=s.join(inputs)
print(s)
#print(inputs)

# %%
# Print second Max Ex: 12 34 23 45 65 o/p:45
ina = [i for i in input().split()]
ina.sort()
print(ina[-2])
# Out:
# 11 23 43 56 72
# ['11', '23', '43', '56', '72']
# 56

# %%
### 3. Print prime numbers up to given range. --> input: 10 output: 2 3 5 7
a=input().split()
def isPrime(n):
    flag = 1
    if n == 2:
        return True
    for i in range(2, n//2 + 1):
        if n % i == 0:
            flag = 0
            return False
    if flag == 1:
        return True

for i in a:
    if isPrime(int(i)):
        print(i)
# Out:
# 5 9 7
# 5
# 7

# %%
# Python program to check if  
# given number is prime or not 
  
nu=input().split()
for num in nu:
    num=int(num)
    # If given number is greater than 1
    if num > 1:
        # Iterate from 2 to n / 2
        for i in range(2, num//2):
            # If num is divisible by any number between
            # 2 and n / 2, it is not prime
            if (num % i) == 0:
                print(num, "is not a prime number")
                break
        else:
            print(num, "is a prime number")
    else:
        print(num, "is not a prime number")

# %%
a=input()
b=input()
k=len(b)
c=0
for i in range(k):
    if a[i]==b[i]:
        c=c+1
print(c)
# Out:
# 5
# 5
# 1

# %%
a=input()
b=input()
k=len(b)
c=0
for i in range(k):
    if a[i]==b[i]:
        c=c+1
print(c)
# Out:
# 010101
# 101101
# 3

# %%
### 4.Print factorial of a given number if it is a prime otherwise print power of the value.
#### test cases : 2
#### 5  --> 120
#### 4 --> 16

# %%
s=input()
li=list(map(int,input().split()))
s2=s[li[0]-1:li[1]]
s2=s2[::-1]
for ch in s[li[1]:]:
    s2+=ch   
print(s2)

# %%
def fact(n):
    s=1
    for i in range(int(n),1,-1):
        s=(s*i)%(10**9+7)
    return s
v=input()
print(fact(v))
# Out:
# 3
# 6

# %%
def fact(n):
    s=[int(v)=1; v=x*v for x in range(int(n),1,-1) if n>=1 ]
    return s
s=input()
print(fact(s))
# Out:
#   File "<ipython-input-27-af56a75dc682>", line 2
#     s=[int(v) v=1;v=x*v for x in range(int(n),1,-1) if n>=1 ]
#               ^
# SyntaxError: invalid syntax

# %%
# Palindromic String
def Plindromic_String(k):
    v=k[::-1]
    if k==v:
        return "YES"
    else:
        return "NO"

string=input()
print(Plindromic_String(string))
# Out:
# aba
# YES

# %%
string=input()
k=string[::-1]
if string==k:
    print("YES")
else:
    print("NO")

# %%
n=int(input())
x = [int(i) for i in input().split()]

def product(x,n):
    y=1
    for i in range(n):
        y=(y*x[i])%(10**9+7)
    return y
 
print(product(x,n))
# Out:
# 5
# 1 2 3 4 5
# 120

# %%
i,j,k=[int(x) for x in input().split()]

def countDivisors(i,j,k):
    c=0
    for m in range(i,j+1):
        if m%k==0:
            c+=1
    print(c)
    
countDivisors(i,j,k)
# Out:
# 1 10 1
# 10

# %%
l=int(input())
n=int(input())
for i in range(1,n+1):
    h=input().split()
    if int(h[0])<l or int(h[1])<l:
        print("UPLOAD ANOTHER")
    elif int(h[0])==l and int(h[1])==l:
        print("ACCEPTED")
    elif int(h[0])>l or int(h[1])>l:
        print("CROP IT")
# Out:
# 180
# 3
# 180 180
# ACCEPTED
# 640 480
# CROP IT
# 120 300
# UPLOAD ANOTHER

# %%
# Write your code here
l=int(input())
n=int(input())
for i in range(1,n+1):
    h=input().split()
    print(size(h))
# Out:
# 180
# 3
# 140 120
# UPLOAD ANOTHER
# 640 480
# CROP IT
# 180 180
# ACCEPTED

# %%
def size(li):
    if int(h[0])<l or int(h[1])<l:
        return "UPLOAD ANOTHER"
    if int(h[0])==l and int(h[1])==l:
        return "ACCEPTED"
    if int(h[0])>l and int(h[1])>l:
        return "CROP IT"

# %%
def size(li):
    if int(h[0])<l or int(h[1])<l:
        return "UPLOAD ANOTHER"
    if int(h[0])==l and int(h[1])==l:
        return "ACCEPTED"
    if int(h[0])>l and int(h[1])>l:
        return "CROP IT"
    
l=int(input())
n=int(input())
for i in range(1,n+1):
    h=input().split()
    print(size(h))
# Out:
# 180
# 3
# 180 160
# UPLOAD ANOTHER
# 640 600
# CROP IT
# 649 700
# CROP IT

# %%
n=int(input())
motu=0
patlu=0
co=0
if patlu=0:
    patlu=patlu+1
if motu=0:
    motu=motu+1
co=patlu+motu
dif=n-co
if dif>1:

# %%
pat = 0
n = int(input())
while True:
    pat+=1
    n-=pat
    if n==0 or n<0:
        print('Patlu')
        break
    n -= 2*pat
    if n==0 or n<0:
        print('Motu')
        break
# Out:
# 3
# Motu
