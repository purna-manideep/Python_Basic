# %% [markdown]
# ## Tuples

# %%
t=() # sintax for tuples decleration
t=(12,"sdc",12.34)
t
# Out:
# (12, 'sdc', 12.34)

# %%
t[0]
# Out:
# 12

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t.count(12)
# Out:
# 1

# %%
t.index('sdc')
# Out:
# 1

# %%
mylist=()
typ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-09f193f296fc> in <module>
#       1 mylist=()
# ----> 2 typ
#
# NameError: name 'typ' is not defined

# %%
word={'name':'sai','branch':'cse'}
print(word,type(word))
# Out:
# {'name': 'sai', 'branch': 'cse'} <class 'dict'>

# %%
print(word['name'])

# %%
word['name']='sairam'
word['name']
# Out:
# 'sairam'

# %%
word={'name':['ayyappa','lakshmi'],'branch':'cse'}

# %%
print(word['name'][1])
# Out:
# a

# %%
print(word['branch'][1])

# %%
for each in word:
    print(each,'------>',word[each][1],)

# %% [markdown]
# ### Mathods in Dictionary

# %% [markdown]
# ### Dict.clear

# %%
#word.clear()
#print(word)

# %%
newWords=word.copy()
print(newWords)
# Out:
# {'name': ['ayyappa', 'lakshmi'], 'branch': 'cse'}

# %% [markdown]
# dict.get(key)

# %%
word.get('name')
# Out:
# ['ayyappa', 'lakshmi']

# %%
fruits_dist={}
c=0
for i in fruits:
    for j in fruits:
        if i==j:
            c+=1
    fruits_dist.update(i,c)
pritn(fruits_dist)
# Out:
# m n k m n
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-c88fbeae4ed3> in <module>
#       6         if i==j:
#       7             c+=1
# ----> 8     fruits_dist.update(i,c)
#       9 pritn(fruits_dist)
#      10
#
# TypeError: update expected at most 1 arguments, got 2

# %%
f=['o','a','m', ' a','m','a']
# fruits=input().split()
fruit_dist={}
for i in f:
    fruit_dist[i]=fruit_dist.get(i,0)+1
print(fruit_dist)
# Out:
# {'o': 1, 'a': 3, 'm': 2}

# %%
for key in fruit_dist.keys():
    print(key,fruit_dist.get(key),sep=":",end=" ")
# Out:
# ('o', 1)
# ('a', 3)
# ('m', 2)

# %%
for key in fruit_dist.items():
    print(key[0],key[1],sep=":")
# Out:
# o:1
# a:3
# m:2

# %%
for k,v in fruit_dist.items():
    print(k,v,sep=":")
# Out:
# o:1
# a:3
# m:2

# %%
fruits_dist.setdefault("Apple",0)
# Out:
# 0

# %%
fruits_dist.setdefault("Apple",6)
# Out:
# 0

# %%
fruit_dist
# Out:
# {'o': 1, 'a': 3, 'm': 2}

# %%
print(sum([int(num) for num in input().split() if len(num)==3 ]))
# Out:
# 0 0 0
# 0

# %%
print('grat' if input() in range(399,500) else 'u need to inprove')
# Out:
# 400
# u need to inprove

# %%
number=[x for x in range(1,int(input())+1) if x%2==0 and x%7==0]
print(number)
# Out:
# 100
# [14, 28, 42, 56, 70, 84, 98]

# %%
numbers=[(x,y,z) for x in range(1,100) for y in range(x,100) for z in range(y,100) if(x**2)+(y**2)==(z**2)]
print(numbers)
# Out:
# [(3, 4, 5), (5, 12, 13), (6, 8, 10), (7, 24, 25), (8, 15, 17), (9, 12, 15), (9, 40, 41), (10, 24, 26), (11, 60, 61), (12, 16, 20), (12, 35, 37), (13, 84, 85), (14, 48, 50), (15, 20, 25), (15, 36, 39), (16, 30, 34), (16, 63, 65), (18, 24, 30), (18, 80, 82), (20, 21, 29), (20, 48, 52), (21, 28, 35), (21, 72, 75), (24, 32, 40), (24, 45, 51), (24, 70, 74), (25, 60, 65), (27, 36, 45), (28, 45, 53), (30, 40, 50), (30, 72, 78), (32, 60, 68), (33, 44, 55), (33, 56, 65), (35, 84, 91), (36, 48, 60), (36, 77, 85), (39, 52, 65), (39, 80, 89), (40, 42, 58), (40, 75, 85), (42, 56, 70), (45, 60, 75), (48, 55, 73), (48, 64, 80), (51, 68, 85), (54, 72, 90), (57, 76, 95), (60, 63, 87), (65, 72, 97)]

# %%
student_marks=[('sairam',[10,30,60]),('gauthami',[40,50,60])]
student_dict={}
for student in student_marks:
    name=student[0]
    marks=sum(student[1])
    student_dict[name]=marks



print(student_dict)
# Out:
# [dict_values([100, 150]), dict_values([100, 150])]
# {'sairam': 100, 'gauthami': 150}

# %%
student_marks=[('sairam',[10,30,60]),('gauthami',[40,50,60])]
student_dict={}
li=[]
for student in student_marks:
    name=student[0]
    marks=sum(student[1])
    student_dict[name]=marks

print(student_dict)
# Out:
# {'sairam': 100, 'gauthami': 150}

# %%
all_marks=student_dict.values()
max_marks=max(all_marks)
for name in student_dict:
    marks=student_dict[name]
    if marks==max_marks:
        print(name,marks)
# Out:
# gauthami 150

# %%
li=[]

# %%
li[1:2]=[45,66]

# %%
li
# Out:
# [45, 66]

# %%
li.insert(1,47)

# %%
li
# Out:
# [45, 47, 66]

# %%
my_li=3,4.6,

# %%
type(my_li)
# Out:
# tuple
