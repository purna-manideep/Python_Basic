# %%
# program for variable decleration

c=0
c=5/2

# %%
# Typefinding function
type(c)
# Out:
# float

# %%
# mathod for decleraing multipule variable with multiple values in single line and finding there type
name,rollno,age='Python',123,23.5
print(type(name),type(rollno),type(age))
# Out:
# <class 'str'> <class 'int'> <class 'float'>

# %%
# programe for variable assinment and swaping
a,b=10,20
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 10 20
# 20 10

# %%
# operators
# Arithmetic operators: Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication and division.
# floor division :-//
# exponention **
2**5
# Out:
# 32

# %%
# Function used for squaring the value heare pow(x,y) heare x is the value and y ins the power factor
pow(3,5)
# Out:
# 243

# %%
# Relational operators these are used for comparing the variables these are "and" and "or" 
# new operators  are membership oerators "in" and "not in"

# Identity operators: this is used to compare the objects they are "is"and "is not"(note:dont use in string because it take the id of string)
5 is not 10
# Out:
# True

# %%
"abc" is "abc"
# Out:
# True

# %%
# conditional control statements:
#these are used to control the follow of program execuation 
# conditional statement: "if" "if else" "elif" "else"

if (5<6):
    print("false")
elif(6<7):
    print("true")
else:
    print("false")
# Out:
# false

# %%
# iterative statements are the loops: "while"  "for"
range(2,10,2)# it is a function used to set the range  value starts from "zero" and ends at "vlue-1" the third value is for the increment position
# Out:
# range(2, 10, 2)

# %%
for x in range(2,10,2):
    print(x,end=",")# the vlues are assinedto x here the end for the indication of ending parameter
# Out:
# 2,4,6,8,
# int

# %%
# jumping statements: "break(it is used to for termination )" and "continue (it will skip and continue to the next loop)"

# %%
# While loop

num=1
while num<6:
    print(num)
    num+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in 1,2,3:
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(10,6-2,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %%
print(1,2)
print(1,2,sep=",",end="*" ) # it use the "sep"  parameter  the values which are used in the parameter in delemeter
print(3,4)
print(3, sep=";")# here it hase the single element so the sep skips
# Out:
# 1 2
# 1,2*3 4
# 3

# %%
list(range(5,10))# to see the vlues in range
# Out:
# [5, 6, 7, 8, 9]

# %%
# input mathod : to take the input from the user

input("enter the value:")# first print the data in string and ask the user for input
# Out:
# enter the value:20
# '20'

# %%
n=input("enter the value:")
print(n)
type(n)
# Out:
# enter the value:12.3
# 12.3
# str

# %%
1+int("2")
# Out:
# 3

# %%
num=10
print(num)
print(Num)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-9fda03b957e7> in <module>
#       1 num=10
#       2 print(num)
# ----> 3 print(Nom)
#
# NameError: name 'Nom' is not defined

# %%
l=[1,20,3]
print(l)
l[1]
l[2]
# Out:
# [1, 20, 3]
# 20

# %%
data=input()
len(data.split())
#print(len(data))
# Out:
# 1 2 3 4
# 4

# %%
# basic mathod for counting the lenth
data=input()
count=0
for char in data.split(" "):
    count+=1
    print(count)
# Out:
# 1 2 3 4
# 1
# 2
# 3
# 4

# %%
data=input().split()
len(data)
# Out:
# 1 2 3 4  5
# 5

# %%
for i in 1,2,3:
    print(i)
print(i)
# Out:
# 1
# 2
# 3
# 3

# %%
# program convert the list into integers and to sumthe values
data=input()
x=data.split(",")
s=0
for x in x:
    s+=int(x)
print(s)

# %%
# type conversion function
l=['1','2','3']
r=[]#empty list
for val in l:
    r.append(int(val))
print(r)
# Out:
# [1, 2, 3]

# %%
data=input()
values=data.split(",")
#map(mathod_name,list_of_values)
int_values=list(map(int,values))
sum(int_values)
# Out:
# 1,2,3
# 6

# %%
a=input()
value=a.split("+")
#s=list(map(int,value))
print(min(s))
print(max(s))
# Out:
# 1+2+4+5+2+3+7+1
# 1
# 7

# %%
a=input()
value=a.split("+")
s=list(map(int,value))
for x in s:
    if
# Out:
#   File "<ipython-input-9-0aa6d489ea3d>", line 5
#     if
#       ^
# SyntaxError: invalid syntax

# %%
t=input()
v=list(map(int,t))
for i in int(v):
    ls=input()
    i+=1
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-72f6636e2f73> in <module>
#       1 t=input()
#       2 v=list(map(int,t))
# ----> 3 for i in int(v):
#       4     ls=input()
#       5     i+=1
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
t=input()
v=map(int,t)
type(v)
# Out:
# 2
# map

# %%
a=input()
